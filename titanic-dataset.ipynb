# %% [markdown]
# ## *1. Setup*
# #### import the modules and load the data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
# ideas for this notebook:

# 1. Logistic regression for classification, with tf and scikit
# 2. Random forest for classification, with tf and scikit
# 3. Neural Networks for classification, with tf and scikit 

# compare the three methods

# %%
# import modules
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow_decision_forests as tfdf

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from matplotlib import pyplot as plt
import seaborn as sns

# options for pandas display
pd.options.display.float_format = "{:.3f}".format # show only three decimals

# %%
# get the data
train_df = pd.read_csv("/kaggle/input/titanic/train.csv")

# shuffle the train dataset to avoid tendencies
traind_df = train_df.reindex(np.random.permutation(train_df.index))

train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.000      1
# 2                               Heikkinen, Miss. Laina  female 26.000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                             Allen, Mr. William Henry    male 35.000      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male 27.000      0
# 887                       Graham, Miss. Margaret Edith  female 19.000      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.000      0
# 890                                Dooley, Mr. Patrick    male 32.000      0
#
#      Parch            Ticket   Fare Cabin Embarked
# 0        0         A/5 21171  7.250   NaN        S
# 1        0          PC 17599 71.283   C85        C
# 2        0  STON/O2. 3101282  7.925   NaN        S
# 3        0            113803 53.100  C123        S
# 4        0            373450  8.050   NaN        S
# ..     ...               ...    ...   ...      ...
# 886      0            211536 13.000   NaN        S
# 887      0            112053 30.000   B42        S
# 888      2        W./C. 6607 23.450   NaN        S
# 889      0            111369 30.000  C148        C
# 890      0            370376  7.750   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_df = pd.read_csv("/kaggle/input/titanic/test.csv")
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex    Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 0      male 34.500      0      0              330911   7.829   NaN        Q
# 1    female 47.000      1      0              363272   7.000   NaN        S
# 2      male 62.000      0      0              240276   9.688   NaN        Q
# 3      male 27.000      0      0              315154   8.662   NaN        S
# 4    female 22.000      1      1             3101298  12.287   NaN        S
# ..      ...    ...    ...    ...                 ...     ...   ...      ...
# 413    male    NaN      0      0           A.5. 3236   8.050   NaN        S
# 414  female 39.000      0      0            PC 17758 108.900  C105        C
# 415    male 38.500      0      0  SOTON/O.Q. 3101262   7.250   NaN        S
# 416    male    NaN      0      0              359309   8.050   NaN        S
# 417    male    NaN      1      1                2668  22.358   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ## *2. Exploratory Data Analysis (EDA)*
# #### visualize the data, found possible errors in it, missing values, looks for hints for the better features, ...

# %%
# visualize the data

# concatenate train and test sets
df = pd.concat([train_df, test_df], axis=0) 
df

# some visualization of the dataset
# print("df info:")
# print()
# df.info()
# print()

print("null values count:")
print()
df.isnull().sum()

# analysis
# so we have missing values for:

# Age (263, about 20%), can be a good feature, we will need to treat this missing values.
# Fare (only 1), we will fill this data and will have no problem, it is only one.
# Cabin (most of the values, more than 75%), difficult to fill with veracity when more than 75% of the values are missing.
# Embarked (only 2), we will fill this data and will have no problem, it is only one.
# Out:
# null values count:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# list with the names of numerical and categorical columns
numerical_columns = ['PassengerId', 'Survived', 'Pclass', 'Fare', 'Age', 'SibSp', 'Parch']
categorical_columns = [x for x in df.columns if x not in numerical_columns]  

# print the .describe() with all de column types
print("data describe:")
print()
df[numerical_columns + categorical_columns].describe(include="all").T

# analysis
# 1. 38,4% of the people survived (not very imbalanced) (the .describe() doesn't count the NaN's when calculating the average)
# 2. 843 males vs 466 female (a little imbalanced)
# 3. SibSp and Parch max of 8 and 9 respectively, which is kind of ok considering the average number of childrens were greater:
# https://populationeducation.org/wp-content/uploads/2020/04/average-number-children-per-us-family-historic-infographic.pdf
# but most people had no (or few) relatives on board, we can see this by the quantiles
# 4.186 unique cabins (of only 295 values, can't categorize by this feature)

# questions
# 1. minimum fare of 0 (15 values)? no explanation for this in the dataset description
# 2. the tickets aren't unique for each person, the same family members get the same ticket? no explanation for this in the dataset description
# not really, sometimes yes sometimes not, better do this by the name of the family
# Out:
# data describe:
#                count unique                   top freq    mean     std   min  \
# PassengerId 1309.000    NaN                   NaN  NaN 655.000 378.020 1.000
# Survived     891.000    NaN                   NaN  NaN   0.384   0.487 0.000
# Pclass      1309.000    NaN                   NaN  NaN   2.295   0.838 1.000
# Fare        1308.000    NaN                   NaN  NaN  33.295  51.759 0.000
# Age         1046.000    NaN                   NaN  NaN  29.881  14.413 0.170
# SibSp       1309.000    NaN                   NaN  NaN   0.499   1.042 0.000
# Parch       1309.000    NaN                   NaN  NaN   0.385   0.866 0.000
# Name            1309   1307  Connolly, Miss. Kate    2     NaN     NaN   NaN
# Sex             1309      2                  male  843     NaN     NaN   NaN
# Ticket          1309    929              CA. 2343   11     NaN     NaN   NaN
# Cabin            295    186           C23 C25 C27    6     NaN     NaN   NaN
# Embarked        1307      3                     S  914     NaN     NaN   NaN
#
#                 25%     50%     75%      max
# PassengerId 328.000 655.000 982.000 1309.000
# Survived      0.000   0.000   1.000    1.000
# Pclass        2.000   3.000   3.000    3.000
# Fare          7.896  14.454  31.275  512.329
# Age          21.000  28.000  39.000   80.000
# SibSp         0.000   0.000   1.000    8.000
# Parch         0.000   0.000   0.000    9.000
# Name            NaN     NaN     NaN      NaN
# Sex             NaN     NaN     NaN      NaN
# Ticket          NaN     NaN     NaN      NaN
# Cabin           NaN     NaN     NaN      NaN
# Embarked        NaN     NaN     NaN      NaN

# %%
# visualization of distributions
# here we use only the train dataframe because we need the Survived values
plt.figure()
sns.pairplot(train_df, hue="Survived")

# analysis
# 1. most people from the Pclass=3 died than lived, in Pclass=1,2 the number is alike
# 2. high (4 or more) SibSp or Parch seems to have died more 

# 3. none of the other distributions seem to indicate a clear line between the people that survived and those who didn't
# in other words, do not show trends of people who survived in function of the features (or a relantionship between features and survived)

# %%
# visualization of correlations
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr().abs(), cmap="Purples", annot=True)

# Analysis
# we dont have much correlation in the dataset
# the most useful one is the 0.34 in Survived x Pclass and it's not great
# Out:
# <AxesSubplot:>

# %%
# try this later 
# !pip install dython
# from dython import nominal
# nominal.associations(df,figsize=(20,10),mark_columns=True)

# %%
# to show all the dataframes
from IPython.display import display_html
from itertools import chain,cycle
def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 style="text-align: center;">{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# check if the data are imbalanced

# male and female who survived
df_temp1 = train_df.groupby(['Sex','Survived'],as_index=False).size().rename(columns={"size":'counts'})
# most female survived while most men died, good feature

# Pclass and their survival
df_temp2 = train_df.groupby(['Pclass','Survived'],as_index=False).size().rename(columns={"size":'counts'})
# the number is kind of equal except for the 3 Pclass where more people died and a little for the 1 Pclass

# SibSp and their survival
df_temp3 = train_df.groupby(['SibSp','Survived'],as_index=False).size().rename(columns={"size":'counts'})
# not much difference of counts in the same values of SibSp, except for zero, where more people died

# Parch and their survival
df_temp4 = train_df.groupby(['Parch','Survived'],as_index=False).size().rename(columns={"size":'counts'})
# in Parch=0 more people die (2/3) for others Parch's there is not much difference

# SibSp + Parch and their survival
df_temp4 = train_df.groupby(['Parch','Survived'],as_index=False).size().rename(columns={"size":'counts'})
# in Parch=0 more people die (2/3) for others Parch's there is not much difference

display_side_by_side(df_temp1,df_temp2,df_temp3,df_temp4, titles=['Sex-Survived','Pclass-Survived',"SibSp-Survived","Parch-Survived"])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sex-Survived</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Sex</th>
#       <th>Survived</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>female</td>
#       <td>0</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>female</td>
#       <td>1</td>
#       <td>233</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>male</td>
#       <td>0</td>
#       <td>468</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>male</td>
#       <td>1</td>
#       <td>109</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Pclass-Survived</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pclass</th>
#       <th>Survived</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>136</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>0</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>1</td>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>0</td>
#       <td>372</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>1</td>
#       <td>119</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">SibSp-Survived</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SibSp</th>
#       <th>Survived</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>398</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>210</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>0</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>1</td>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>0</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3</td>
#       <td>0</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>3</td>
#       <td>1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4</td>
#       <td>0</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>4</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>5</td>
#       <td>0</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>8</td>
#       <td>0</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Parch-Survived</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Parch</th>
#       <th>Survived</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>445</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>1</td>
#       <td>233</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>0</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>1</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>0</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>1</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3</td>
#       <td>0</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>3</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4</td>
#       <td>0</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>5</td>
#       <td>0</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>5</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>6</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# ## *Data Preprocessing*

# %%
# check if age has a correlation with sex

# group by sex and age
df_temp = train_df.groupby(['Sex','Age'],as_index=False).size().rename(columns={"size":'counts'})

# histogram of age divided by sex
plt.subplot(1, 2, 1)
plt.hist(df_temp[df_temp["Sex"]=="female"]["Age"], weights=df_temp[df_temp["Sex"]=="female"]["counts"] )
plt.title("Female")
plt.xlim(0,80)
plt.xlabel("Age")
plt.subplot(1, 2, 2)
plt.hist(df_temp[df_temp["Sex"]=="male"]["Age"], weights=df_temp[df_temp["Sex"]=="male"]["counts"] )
plt.title("Male")
plt.xlim(0,80)
plt.xlabel("Age")
plt.tight_layout()
plt.show()

# %%
# treat the data

# lets start by filling the NaN's in age 
# Pclass has a correlation of 0.41 with age, sex seems to have low correlation, we will group by Pclass
# creates a dataframe grouped by Pclass with the mean of Age for each Pclass (contains columns Mean Age, Pclass and others)
df_temp = df.groupby("Pclass", as_index=False).mean().rename(columns={"Age":"Mean Age"})

# creates a dictionary from Pclass to medium age
dict_temp = dict(zip(df_temp["Pclass"], df_temp["Mean Age"]))

# fill the nan's mapping the dictionary 
df["Age"] = df["Age"].fillna(df["Pclass"].map(dict_temp))



# then normalize the fare column by the Z-score
# df["Fare"] = ( df["Fare"]-df["Fare"].mean() ) / df["Fare"].std() 

# then normalize the fare column between 0 and 1
df["Fare"] = df["Fare"] / df["Fare"].max()


# creates a new column in the dataframe with the family size 
df["FamilySize"] = df["SibSp"] + df["Parch"]


df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1     0.000       3
# 1              2     1.000       1
# 2              3     1.000       3
# 3              4     1.000       1
# 4              5     0.000       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.000      1
# 2                               Heikkinen, Miss. Laina  female 26.000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.000      1
# 4                             Allen, Mr. William Henry    male 35.000      0
# ..                                                 ...     ...    ...    ...
# 413                                 Spector, Mr. Woolf    male 24.816      0
# 414                       Oliva y Ocana, Dona. Fermina  female 39.000      0
# 415                       Saether, Mr. Simon Sivertsen    male 38.500      0
# 416                                Ware, Mr. Frederick    male 24.816      0
# 417                           Peter, Master. Michael J    male 24.816      1
#
#      Parch              Ticket  Fare Cabin Embarked  FamilySize
# 0        0           A/5 21171 0.014   NaN        S           1
# 1        0            PC 17599 0.139   C85        C           1
# 2        0    STON/O2. 3101282 0.015   NaN        S           0
# 3        0              113803 0.104  C123        S           1
# 4        0              373450 0.016   NaN        S           0
# ..     ...                 ...   ...   ...      ...         ...
# 413      0           A.5. 3236 0.016   NaN        S           0
# 414      0            PC 17758 0.213  C105        C           0
# 415      0  SOTON/O.Q. 3101262 0.014   NaN        S           0
# 416      0              359309 0.016   NaN        S           0
# 417      1                2668 0.044   NaN        C           2
#
# [1309 rows x 13 columns]

# %%
# split the data back in train and test sets after treated
train_df_treated = df.iloc[:890]
test_df_treated = df.iloc[891:].drop(["Survived"], axis=1)
# all values of "Survived" were NaN

# %% [markdown]
# ## *3. Building and comparing three diferent ML models*
# ### 3.1 Logistic Regression - TensorFlow
# ### 3.2 Random Forests - TensorFlow
# ### 3.3 Gradient Boosted Trees - TensorFlow

# %% [markdown]
# ### *3.1 Logistic Regression - TensorFlow*
#
# #### heavily based on the Google ML Crash Course

# %%
# creates the feature layer

# list with the name of the numerical features
list_numerical_features = ["Fare"]

# list with the name of the bucketized features
list_bucketized_features = ["Age", "FamilySize"]
# dictionary with resolution of intervals of each bucketized feature
dict_bucketized_features = {"Age":10, "FamilySize":2}

# list with categorical features  
list_categorical_features = ["Sex", "Pclass"]
# dictionary with vocabulary of each categorical feature
dict_categorical_features = {"Sex":["male","female"], "Pclass":[1,2,3]}



# join all the features
list_features = []
list_features.extend(list_numerical_features[:])
list_features.extend(list_bucketized_features[:])
list_features.extend(list_categorical_features[:])

# list with the feature columns
feature_columns = []


# creates the feature columns

# create numerical feature columns
for name in list_numerical_features:
    feature_columns.append(tf.feature_column.numeric_column(name))
    
# create bucketized feature columns
for name in list_bucketized_features:
    numeric = tf.feature_column.numeric_column(name)
    boundaries = list(np.arange( int(min(df[name])), int(max(df[name])), dict_bucketized_features[name] ))
    bucketized_feature = tf.feature_column.bucketized_column(numeric, boundaries=boundaries)
    feature_columns.append(bucketized_feature)
    
# create categorical feature columns
for name in list_categorical_features:    
    categorical_feature = tf.feature_column.categorical_column_with_vocabulary_list(key=name, vocabulary_list=dict_categorical_features[name], default_value=0)
    embedded_group_column = tf.feature_column.embedding_column(categorical_feature,dimension=len(dict_categorical_features[name]))
    feature_columns.append(embedded_group_column)
    

# shows the feature columns to see if everything is allright
print(feature_columns)
    
# finally
# convert the features into a layer
feature_layer = layers.DenseFeatures(feature_columns)
# Out:
# [NumericColumn(key='Fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), BucketizedColumn(source_column=NumericColumn(key='Age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(0, 10, 20, 30, 40, 50, 60, 70)), BucketizedColumn(source_column=NumericColumn(key='FamilySize', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(0, 2, 4, 6, 8)), EmbeddingColumn(categorical_column=VocabularyListCategoricalColumn(key='Sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=0, num_oov_buckets=0), dimension=2, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f4516b637d0>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True, use_safe_embedding_lookup=True), EmbeddingColumn(categorical_column=VocabularyListCategoricalColumn(key='Pclass', vocabulary_list=(1, 2, 3), dtype=tf.int64, default_value=0, num_oov_buckets=0), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x7f4516b63e10>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True, use_safe_embedding_lookup=True)]

# %%
# functions that create and train a model

# classification model
def Create_Model(learning_rate, feature_layer, metrics):
    
    # sequential model
    model = tf.keras.models.Sequential()
    
    # add the feature layer we created
    model.add(feature_layer)
    
    # pass the regression value trough a sigmoid activation
    model.add(tf.keras.layers.Dense(units=1, input_shape=(1,), activation=tf.sigmoid))
    
    # compile into a model that tensorflow can execute with a Binary Cross Entropy loss function
    model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=learning_rate), 
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), metrics=metrics)
    
    return model


# train the model
def Train_Model(model, dataset, epochs, label_name, batch_size=None, shuffle=True):
    
    # create dict with name of the features and numpy arrays of its values for each feature
    features = {name:np.array(value) for name, value in dataset.items()}
    
    # removes the label from features and puts it into variable label
    label = np.array(features.pop(label_name))
    
    # trains the model for a fixed number of epochs
    history = model.fit(x=features, y=label, batch_size=batch_size, epochs=epochs, shuffle=shuffle, verbose=1)
    
    # the list of epochs
    epochs_list = history.epoch
    
    # classification metrics (training loss values and metric values [and validation if applicable]) for each epoch
    classification_metrics_history = pd.DataFrame(history.history)
    
    return epochs_list, classification_metrics_history

# %%
# defines the plotting function 

def Plot_Curve(epochs_list, classification_metrics_history, list_of_metrics):
    #plot the curves of one or more classification metrics vs epoch
    # list_of_metrics should be one of the names shown in:
    # https://www.tensorflow.org/tutorials/structured_data/imbalanced_data#define_the_model_and_metrics  
    
    plt.figure()
    plt.xlabel("epoch")
    plt.ylabel("Value")
    
    for metric in list_of_metrics:
        x = classification_metrics_history[metric]
        plt.plot(epochs_list[1:], x[1:], label=metric)
        
    plt.legend()

# %%
# Set the hyperparameters, train the model and plot the result of training

# hyperparameters 

# output values above the classification_threshold will be considered as survived (1), below as dead (0)
classification_threshold = 0.65
# the multiplication factor of the gradient update
learning_rate = 0.005
# how many iterations over the whole datset
epochs = 100
# number of iterations (values) before gradient calculation and update
batch_size = 100

# creates the label name
label_name = "Survived"

# the metrics the model will measure
metrics = [tf.keras.metrics.BinaryAccuracy(name="accuracy", threshold=classification_threshold),
           tf.keras.metrics.Precision(name="precision", thresholds=classification_threshold),
           tf.keras.metrics.Recall(name="recall", thresholds=classification_threshold),
           tf.keras.metrics.AUC(name="auc", num_thresholds=100),
          ]

# creates the model 
model = Create_Model(learning_rate, feature_layer, metrics)

# dataframe with only the columns we will use
df_temp = pd.concat([train_df_treated[list_features], train_df_treated[label_name]], axis=1)

# train the model on the training set
epochs_list, classification_metrics_history = Train_Model(model, df_temp, epochs, label_name, batch_size)

# plot the graphs of the chosen metrics vs epochs 
list_of_metrics_to_plot = ["accuracy"]
Plot_Curve(epochs_list, classification_metrics_history, list_of_metrics_to_plot)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 2s 2ms/step - loss: 0.7644 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4935
# Epoch 2/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7434 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5968
# Epoch 3/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7291 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6529
# Epoch 4/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7178 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6996
# Epoch 5/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7083 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7277
# Epoch 6/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7004 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7570
# Epoch 7/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7786
# Epoch 8/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6880 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7999
# Epoch 9/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.6157 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8039
# Epoch 10/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6782 - accuracy: 0.6483 - precision: 1.0000 - recall: 0.0848 - auc: 0.8115
# Epoch 11/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.6674 - precision: 1.0000 - recall: 0.1345 - auc: 0.8162
# Epoch 12/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6696 - accuracy: 0.6764 - precision: 0.9655 - recall: 0.1637 - auc: 0.8205
# Epoch 13/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6656 - accuracy: 0.6809 - precision: 0.9677 - recall: 0.1754 - auc: 0.8248
# Epoch 14/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6617 - accuracy: 0.6899 - precision: 0.9583 - recall: 0.2018 - auc: 0.8293
# Epoch 15/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6581 - accuracy: 0.7157 - precision: 0.9684 - recall: 0.2690 - auc: 0.8299
# Epoch 16/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6546 - accuracy: 0.7213 - precision: 0.9700 - recall: 0.2836 - auc: 0.8312
# Epoch 17/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6515 - accuracy: 0.7427 - precision: 0.9669 - recall: 0.3421 - auc: 0.8350
# Epoch 18/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6487 - accuracy: 0.7618 - precision: 0.9577 - recall: 0.3977 - auc: 0.8380
# Epoch 19/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6463 - accuracy: 0.7652 - precision: 0.9586 - recall: 0.4064 - auc: 0.8367
# Epoch 20/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.7820 - precision: 0.9512 - recall: 0.4561 - auc: 0.8368
# Epoch 21/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6423 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8399
# Epoch 22/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6406 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8395
# Epoch 23/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6393 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8388
# Epoch 24/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6380 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8390
# Epoch 25/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6370 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8396
# Epoch 26/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6361 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8396
# Epoch 27/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6354 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8384
# Epoch 28/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6347 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8394
# Epoch 29/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6341 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8395
# Epoch 30/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6336 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8400
# Epoch 31/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6331 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8405
# Epoch 32/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6327 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8390
# Epoch 33/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6323 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8402
# Epoch 34/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6321 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8406
# Epoch 35/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6318 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8423
# Epoch 36/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6316 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8432
# Epoch 37/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8443
# Epoch 38/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6312 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8413
# Epoch 39/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6311 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8399
# Epoch 40/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6308 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8403
# Epoch 41/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6307 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8397
# Epoch 42/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6306 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8395
# Epoch 43/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6304 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8406
# Epoch 44/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6303 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8401
# Epoch 45/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6302 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8417
# Epoch 46/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6301 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8408
# Epoch 47/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6299 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8247
# Epoch 48/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6300 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8219
# Epoch 49/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6298 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8228
# Epoch 50/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6297 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8214
# Epoch 51/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6296 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8205
# Epoch 52/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8202
# Epoch 53/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8205
# Epoch 54/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6293 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8179
# Epoch 55/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6293 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8099
# Epoch 56/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6292 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8062
# Epoch 57/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6292 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8058
# Epoch 58/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6291 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8062
# Epoch 59/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6290 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8070
# Epoch 60/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6289 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8066
# Epoch 61/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6288 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8041
# Epoch 62/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6288 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8040
# Epoch 63/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6288 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8037
# Epoch 64/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6289 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8036
# Epoch 65/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8042
# Epoch 66/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8036
# Epoch 67/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6286 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8040
# Epoch 68/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6284 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8040
# Epoch 69/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6284 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8041
# Epoch 70/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6284 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8047
# Epoch 71/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6283 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8050
# Epoch 72/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6284 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8035
# Epoch 73/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6282 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8049
# Epoch 74/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6282 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8033
# Epoch 75/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6281 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8022
# Epoch 76/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6281 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8033
# Epoch 77/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6280 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8018
# Epoch 78/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6281 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8018
# Epoch 79/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6280 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8023
# Epoch 80/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8026
# Epoch 81/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8022
# Epoch 82/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8024
# Epoch 83/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.7933 - precision: 0.9489 - recall: 0.4883 - auc: 0.8018
# Epoch 84/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8021
# Epoch 85/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6277 - accuracy: 0.7865 - precision: 0.9419 - recall: 0.4737 - auc: 0.8026
# Epoch 86/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6277 - accuracy: 0.7888 - precision: 0.9477 - recall: 0.4766 - auc: 0.8026
# Epoch 87/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6276 - accuracy: 0.7921 - precision: 0.9486 - recall: 0.4854 - auc: 0.8026
# Epoch 88/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.7888 - precision: 0.9425 - recall: 0.4795 - auc: 0.8023
# Epoch 89/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6277 - accuracy: 0.7865 - precision: 0.9471 - recall: 0.4708 - auc: 0.8024
# Epoch 90/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6276 - accuracy: 0.7888 - precision: 0.9477 - recall: 0.4766 - auc: 0.8026
# Epoch 91/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6275 - accuracy: 0.7933 - precision: 0.9438 - recall: 0.4912 - auc: 0.8029
# Epoch 92/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6275 - accuracy: 0.7888 - precision: 0.9477 - recall: 0.4766 - auc: 0.8022
# Epoch 93/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6275 - accuracy: 0.7933 - precision: 0.9438 - recall: 0.4912 - auc: 0.8024
# Epoch 94/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6275 - accuracy: 0.7933 - precision: 0.9438 - recall: 0.4912 - auc: 0.8023
# Epoch 95/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6275 - accuracy: 0.7899 - precision: 0.9429 - recall: 0.4825 - auc: 0.8020
# Epoch 96/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6273 - accuracy: 0.7933 - precision: 0.9438 - recall: 0.4912 - auc: 0.8025
# Epoch 97/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6275 - accuracy: 0.7921 - precision: 0.9435 - recall: 0.4883 - auc: 0.8024
# Epoch 98/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6273 - accuracy: 0.7933 - precision: 0.9438 - recall: 0.4912 - auc: 0.8026
# Epoch 99/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6273 - accuracy: 0.7933 - precision: 0.9438 - recall: 0.4912 - auc: 0.8027
# Epoch 100/100
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6273 - accuracy: 0.7933 - precision: 0.9438 - recall: 0.4912 - auc: 0.8022

# %%
# evaluate the model against the test set

# create a dict with name of the features and numpy arrays of its values - of the test set
features = {name:np.array(value) for name, value in test_df_treated[list_features].items()}

# if you have a test set with label:
# separates the label
# label = np.array(features.pop(label_name))
# evaluate the model
# model.evaluate(x=features, y=label, batch_size=batch_size)

# if you have a test set without label (our case) and has to make predictions:
predictions = model.predict(x=features, batch_size=batch_size) # numpy array

# transform into 0's and 1's according to the classification threshold  
predictions = (predictions > classification_threshold).astype(int)

# check if there are any problems (Nan's)
if np.sum(np.isnan(predictions))==0:
    print("Zero NaN's")
else:
    print("There are {} NaN's".format(np.sum(np.isnan(predictions))) )
# Out:
# Zero NaN's

# %%
# creates the submission file

# gets the PassengerId column of the test data
passengerid_df = pd.DataFrame(test_df_treated["PassengerId"], columns=["PassengerId"])
# transforms predicions into dataframe
predictions_df = pd.DataFrame(predictions, columns=["Survived"])

# join in one dataframe with two columns
submission_df = pd.concat([passengerid_df, predictions_df], axis=1)

# checks again if everything is alright
print(submission_df)

# save the predictions into a csv file
submission_df.to_csv("TitanicPredictions_LogisticRegression_TF.csv", index=False, sep=",")
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# #### *3.1.2 Logistic Regression - TensorFlow*
# #### Results
#
# This model ended up with accuracy = 0.7933, loss = 0.6273, precision = 0.9438, recall = 0.4912, auc = 0.8022.
#
# This model used only 5 columns of the 13 available in the data.
#
# After submitting to Kaggle these predictions get an Score of 0.54545

# %% [markdown]
# ### *4.2 Random Forest - TensorFlow*
#
# #### Now use the second method, Random Forests

# %%
# Convert the dataset into a TensorFlow dataset.
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df_treated, label="Survived")
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df_treated)

# %%
# TF-DF supports all these feature types (numerical, categorical, ...) natively (differently than NN based models), 
# therefore there is no need for preprocessing in the form of one-hot encoding, normalization or extra is_present feature.
# Labels are a bit different: Keras metrics expect integers. Which is no problem in the Titanic case.

# Train a Random Forest model.
model_rf = tfdf.keras.RandomForestModel(verbose=0)
fitting = model_rf.fit(train_ds)

# Calling compile on the model before the fit is optional. 
# Compile can be used to provide extra evaluation metrics.
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow_decision_forests/keras/core.py:1612: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   features_dataframe = dataframe.drop(label, 1)
# 14/14 [==============================] - 0s 2ms/step
# [INFO kernel.cc:736] Start Yggdrasil model training
# [INFO kernel.cc:737] Collect training examples
# [INFO kernel.cc:392] Number of batches: 14
# [INFO kernel.cc:393] Number of examples: 890
# [INFO data_spec_inference.cc:290] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO data_spec_inference.cc:290] 890 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO data_spec_inference.cc:290] 672 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:759] Dataset:
# Number of records: 890
# Number of columns: 13
#
# Number of columns by type:
# 	NUMERICAL: 7 (53.8462%)
# 	CATEGORICAL: 6 (46.1538%)
#
# Columns:
#
# NUMERICAL: 7 (53.8462%)
# 	0: "Age" NUMERICAL mean:29.2669 min:0.42 max:80 sd:13.2484
# 	3: "FamilySize" NUMERICAL mean:0.905618 min:0 max:10 sd:1.61317
# 	4: "Fare" NUMERICAL mean:0.0629121 min:0 max:1 sd:0.0969819
# 	6: "Parch" NUMERICAL mean:0.382022 min:0 max:6 sd:0.805956
# 	7: "PassengerId" NUMERICAL mean:445.5 min:1 max:890 sd:256.921
# 	8: "Pclass" NUMERICAL mean:2.30787 min:1 max:3 sd:0.83575
# 	10: "SibSp" NUMERICAL mean:0.523596 min:0 max:8 sd:1.1026
#
# CATEGORICAL: 6 (46.1538%)
# 	1: "Cabin" CATEGORICAL num-nas:686 (77.0787%) has-dict vocab-size:1 num-oods:147 (72.0588%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224719%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.5225%)
# 	5: "Name" CATEGORICAL has-dict vocab-size:1 num-oods:890 (100%)
# 	9: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 576 (64.7191%)
# 	11: "Ticket" CATEGORICAL has-dict vocab-size:9 num-oods:672 (75.5056%) most-frequent:"<OOD>" 672 (75.5056%)
# 	12: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:762] Configure learner
# [INFO kernel.cc:787] Training config:
# learner: "RANDOM_FOREST"
# features: "Age"
# features: "Cabin"
# features: "Embarked"
# features: "FamilySize"
# features: "Fare"
# features: "Name"
# features: "Parch"
# features: "PassengerId"
# features: "Pclass"
# features: "Sex"
# features: "SibSp"
# features: "Ticket"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 16
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   winner_take_all_inference: true
#   compute_oob_performances: true
#   compute_oob_variable_importances: false
#   adapt_bootstrap_size_ratio_for_maximum_training_duration: false
# }
#
# [INFO kernel.cc:790] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:817] Train model
# [INFO random_forest.cc:315] Training random forest on 890 example(s) and 12 feature(s).
# [INFO random_forest.cc:628] Training of tree  1/300 (tree index:2) done accuracy:0.776074 logloss:8.07112
# [INFO random_forest.cc:628] Training of tree  11/300 (tree index:10) done accuracy:0.824462 logloss:3.0257
# [INFO random_forest.cc:628] Training of tree  21/300 (tree index:22) done accuracy:0.821348 logloss:2.02129
# [INFO random_forest.cc:628] Training of tree  31/300 (tree index:30) done accuracy:0.82809 logloss:1.59993
# [INFO random_forest.cc:628] Training of tree  41/300 (tree index:39) done accuracy:0.824719 logloss:1.45047
# [INFO random_forest.cc:628] Training of tree  51/300 (tree index:52) done accuracy:0.830337 logloss:1.33887
# [INFO random_forest.cc:628] Training of tree  61/300 (tree index:59) done accuracy:0.834831 logloss:1.26064
# [INFO random_forest.cc:628] Training of tree  71/300 (tree index:70) done accuracy:0.830337 logloss:1.14727
# [INFO random_forest.cc:628] Training of tree  81/300 (tree index:82) done accuracy:0.833708 logloss:1.07638
# [INFO random_forest.cc:628] Training of tree  91/300 (tree index:90) done accuracy:0.830337 logloss:1.00338
# [INFO random_forest.cc:628] Training of tree  101/300 (tree index:100) done accuracy:0.825843 logloss:0.966691
# [INFO random_forest.cc:628] Training of tree  111/300 (tree index:111) done accuracy:0.825843 logloss:0.85861
# [INFO random_forest.cc:628] Training of tree  121/300 (tree index:122) done accuracy:0.826966 logloss:0.675905
# [INFO random_forest.cc:628] Training of tree  131/300 (tree index:130) done accuracy:0.823596 logloss:0.677509
# [INFO random_forest.cc:628] Training of tree  141/300 (tree index:141) done accuracy:0.823596 logloss:0.568766
# [INFO random_forest.cc:628] Training of tree  151/300 (tree index:150) done accuracy:0.825843 logloss:0.568806
# [INFO random_forest.cc:628] Training of tree  161/300 (tree index:162) done accuracy:0.824719 logloss:0.569675
# [INFO random_forest.cc:628] Training of tree  172/300 (tree index:169) done accuracy:0.824719 logloss:0.570168
# [INFO random_forest.cc:628] Training of tree  183/300 (tree index:184) done accuracy:0.825843 logloss:0.572782
# [INFO random_forest.cc:628] Training of tree  193/300 (tree index:192) done accuracy:0.823596 logloss:0.571377
# [INFO random_forest.cc:628] Training of tree  203/300 (tree index:203) done accuracy:0.826966 logloss:0.571283
# [INFO random_forest.cc:628] Training of tree  213/300 (tree index:214) done accuracy:0.822472 logloss:0.570475
# [INFO random_forest.cc:628] Training of tree  223/300 (tree index:223) done accuracy:0.824719 logloss:0.532392
# [INFO random_forest.cc:628] Training of tree  233/300 (tree index:232) done accuracy:0.822472 logloss:0.533455
# [INFO random_forest.cc:628] Training of tree  245/300 (tree index:241) done accuracy:0.824719 logloss:0.532388
# [INFO random_forest.cc:628] Training of tree  255/300 (tree index:249) done accuracy:0.82809 logloss:0.532399
# [INFO random_forest.cc:628] Training of tree  265/300 (tree index:261) done accuracy:0.829214 logloss:0.533568
# [INFO random_forest.cc:628] Training of tree  275/300 (tree index:275) done accuracy:0.831461 logloss:0.533211
# [INFO random_forest.cc:628] Training of tree  285/300 (tree index:285) done accuracy:0.830337 logloss:0.533058
# [INFO random_forest.cc:628] Training of tree  295/300 (tree index:296) done accuracy:0.829214 logloss:0.533851
# [INFO random_forest.cc:628] Training of tree  300/300 (tree index:298) done accuracy:0.830337 logloss:0.534503
# [INFO random_forest.cc:696] Final OOB metrics: accuracy:0.830337 logloss:0.534503
# [INFO kernel.cc:828] Export model in log directory: /tmp/tmp2ehvxgwo
# [INFO kernel.cc:836] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO decision_forest.cc:590] Model loaded with 300 root(s), 44138 node(s), and 10 input feature(s).
# [INFO abstract_model.cc:993] Engine "RandomForestOptPred" built
# [INFO kernel.cc:848] Use fast generic engine

# %%
# Other options to analyze the model:

# Summary of the model structure to see:
# Type: The learning algorithm used to train the model (Random Forest in our case).
# Task: The problem solved by the model (Classification in our case).
# Input Features: The input features of the model.
# Variable Importance: Different measures of the importance of each feature for the model.
# Out-of-bag evaluation: The out-of-bag evaluation of the model. This is a cheap and efficient alternative to cross-validation.
# Number of {trees, nodes} and other metrics: Statistics about the structure of the decisions forests.
model_rf.summary()


# Evaluate the model against a test set (that means, dataset not used in training and with label):
# model_1.compile(metrics=["accuracy"])
# evaluation = model_rf.evaluate(test_ds, return_dict=True)
# print()
# for name, value in evaluation.items():
#   print(f"{name}: {value:.4f}")


# to plot the trees diagram to visualize the decision nodes and the information gain:
#tfdf.model_plotter.plot_model_in_colab(model_rf, tree_idx=0, max_depth=3)
# Out:
# Model: "random_forest_model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (12):
# 	Age
# 	Cabin
# 	Embarked
# 	FamilySize
# 	Fare
# 	Name
# 	Parch
# 	PassengerId
# 	Pclass
# 	Sex
# 	SibSp
# 	Ticket
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.       "Cabin"  8.286783 ################
#     2.        "Name"  8.286783 ################
#     3.     "__LABEL"  8.286783 ################
#     4.       "SibSp"  7.806303 ##############
#     5.       "Parch"  7.719983 ##############
#     6.    "Embarked"  6.745097 ############
#     7.  "FamilySize"  6.662628 ############
#     8.      "Ticket"  5.732868 ##########
#     9. "PassengerId"  4.908354 ########
#    10.      "Pclass"  3.577643 #####
#    11.         "Age"  3.572734 #####
#    12.        "Fare"  2.909645 ####
#    13.         "Sex"  1.020353
#
# Variable Importance: NUM_AS_ROOT:
#     1.        "Sex" 142.000000 ################
#     2.     "Pclass" 76.000000 ########
#     3.       "Fare" 53.000000 #####
#     4.     "Ticket" 18.000000 #
#     5. "FamilySize"  8.000000
#     6.        "Age"  2.000000
#     7.      "Parch"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "PassengerId" 7003.000000 ################
#     2.        "Fare" 5370.000000 ############
#     3.         "Age" 5254.000000 ###########
#     4.    "Embarked" 902.000000 #
#     5.  "FamilySize" 817.000000 #
#     6.      "Pclass" 711.000000
#     7.         "Sex" 593.000000
#     8.       "SibSp" 480.000000
#     9.      "Ticket" 406.000000
#    10.       "Parch" 383.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "Sex" 38831.123941 ################
#     2.        "Fare" 24505.794837 #########
#     3. "PassengerId" 22635.332360 #########
#     4.         "Age" 22488.197625 #########
#     5.      "Pclass" 13016.212801 ####
#     6.  "FamilySize" 4822.052444 #
#     7.      "Ticket" 4725.538074 #
#     8.    "Embarked" 3524.719979
#     9.       "SibSp" 1934.054416
#    10.       "Parch" 1418.923725
#
#
#
# Winner take all: true
# Out-of-bag evaluation: accuracy:0.830337 logloss:0.534503
# Number of trees: 300
# Total number of nodes: 44138
#
# Number of nodes by tree:
# Count: 300 Average: 147.127 StdDev: 9.53715
# Min: 117 Max: 171 Ignored: 0
# ----------------------------------------------
# [ 117, 119)  1   0.33%   0.33%
# [ 119, 122)  1   0.33%   0.67%
# [ 122, 125)  1   0.33%   1.00%
# [ 125, 128)  5   1.67%   2.67% #
# [ 128, 130)  4   1.33%   4.00% #
# [ 130, 133)  7   2.33%   6.33% #
# [ 133, 136) 19   6.33%  12.67% ###
# [ 136, 139) 14   4.67%  17.33% ##
# [ 139, 141) 15   5.00%  22.33% ###
# [ 141, 144) 37  12.33%  34.67% ######
# [ 144, 147) 25   8.33%  43.00% ####
# [ 147, 150) 59  19.67%  62.67% ##########
# [ 150, 152) 22   7.33%  70.00% ####
# [ 152, 155) 18   6.00%  76.00% ###
# [ 155, 158) 36  12.00%  88.00% ######
# [ 158, 161)  8   2.67%  90.67% #
# [ 161, 163)  8   2.67%  93.33% #
# [ 163, 166) 16   5.33%  98.67% ###
# [ 166, 169)  2   0.67%  99.33%
# [ 169, 171]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 22219 Average: 8.2889 StdDev: 2.73674
# Min: 1 Max: 15 Ignored: 0
# ----------------------------------------------
# [  1,  2)   18   0.08%   0.08%
# [  2,  3)   74   0.33%   0.41%
# [  3,  4)  450   2.03%   2.44% #
# [  4,  5) 1146   5.16%   7.60% ####
# [  5,  6) 1945   8.75%  16.35% ######
# [  6,  7) 2502  11.26%  27.61% ########
# [  7,  8) 2982  13.42%  41.03% ##########
# [  8,  9) 3132  14.10%  55.13% ##########
# [  9, 10) 2837  12.77%  67.90% #########
# [ 10, 11) 2413  10.86%  78.76% ########
# [ 11, 12) 1787   8.04%  86.80% ######
# [ 12, 13) 1262   5.68%  92.48% ####
# [ 13, 14)  812   3.65%  96.13% ###
# [ 14, 15)  501   2.25%  98.39% ##
# [ 15, 15]  358   1.61% 100.00% #
#
# Number of training obs by leaf:
# Count: 22219 Average: 12.0167 StdDev: 13.9342
# Min: 5 Max: 160 Ignored: 0
# ----------------------------------------------
# [   5,  12) 16898  76.05%  76.05% ##########
# [  12,  20)  2378  10.70%  86.75% #
# [  20,  28)  1083   4.87%  91.63% #
# [  28,  36)   590   2.66%  94.28%
# [  36,  44)   356   1.60%  95.89%
# [  44,  51)   240   1.08%  96.97%
# [  51,  59)   176   0.79%  97.76%
# [  59,  67)   116   0.52%  98.28%
# [  67,  75)    90   0.41%  98.69%
# [  75,  83)    88   0.40%  99.08%
# [  83,  90)    58   0.26%  99.34%
# [  90,  98)    57   0.26%  99.60%
# [  98, 106)    48   0.22%  99.82%
# [ 106, 114)    21   0.09%  99.91%
# [ 114, 122)    11   0.05%  99.96%
# [ 122, 129)     3   0.01%  99.97%
# [ 129, 137)     4   0.02%  99.99%
# [ 137, 145)     0   0.00%  99.99%
# [ 145, 153)     1   0.00% 100.00%
# [ 153, 160]     1   0.00% 100.00%
#
# Attribute in nodes:
# 	7003 : PassengerId [NUMERICAL]
# 	5370 : Fare [NUMERICAL]
# 	5254 : Age [NUMERICAL]
# 	902 : Embarked [CATEGORICAL]
# 	817 : FamilySize [NUMERICAL]
# 	711 : Pclass [NUMERICAL]
# 	593 : Sex [CATEGORICAL]
# 	480 : SibSp [NUMERICAL]
# 	406 : Ticket [CATEGORICAL]
# 	383 : Parch [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	142 : Sex [CATEGORICAL]
# 	76 : Pclass [NUMERICAL]
# 	53 : Fare [NUMERICAL]
# 	18 : Ticket [CATEGORICAL]
# 	8 : FamilySize [NUMERICAL]
# 	2 : Age [NUMERICAL]
# 	1 : Parch [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	296 : Sex [CATEGORICAL]
# 	182 : Pclass [NUMERICAL]
# 	155 : Fare [NUMERICAL]
# 	81 : Ticket [CATEGORICAL]
# 	72 : Age [NUMERICAL]
# 	51 : FamilySize [NUMERICAL]
# 	23 : Embarked [CATEGORICAL]
# 	8 : PassengerId [NUMERICAL]
# 	7 : SibSp [NUMERICAL]
# 	7 : Parch [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	422 : Sex [CATEGORICAL]
# 	377 : Fare [NUMERICAL]
# 	297 : Pclass [NUMERICAL]
# 	275 : Age [NUMERICAL]
# 	228 : Ticket [CATEGORICAL]
# 	150 : FamilySize [NUMERICAL]
# 	92 : PassengerId [NUMERICAL]
# 	66 : Embarked [CATEGORICAL]
# 	42 : SibSp [NUMERICAL]
# 	23 : Parch [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	730 : Age [NUMERICAL]
# 	721 : Fare [NUMERICAL]
# 	502 : Sex [CATEGORICAL]
# 	468 : PassengerId [NUMERICAL]
# 	401 : Pclass [NUMERICAL]
# 	311 : Ticket [CATEGORICAL]
# 	260 : FamilySize [NUMERICAL]
# 	152 : Embarked [CATEGORICAL]
# 	83 : SibSp [NUMERICAL]
# 	74 : Parch [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	2020 : Age [NUMERICAL]
# 	1986 : PassengerId [NUMERICAL]
# 	1943 : Fare [NUMERICAL]
# 	570 : Sex [CATEGORICAL]
# 	551 : Pclass [NUMERICAL]
# 	493 : FamilySize [NUMERICAL]
# 	379 : Ticket [CATEGORICAL]
# 	366 : Embarked [CATEGORICAL]
# 	197 : Parch [NUMERICAL]
# 	194 : SibSp [NUMERICAL]
#
# Condition type in nodes:
# 	20018 : HigherCondition
# 	1901 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	160 : ContainsBitmapCondition
# 	140 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	482 : HigherCondition
# 	400 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	1256 : HigherCondition
# 	716 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	2737 : HigherCondition
# 	965 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	7384 : HigherCondition
# 	1315 : ContainsBitmapCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.776074 logloss:8.07112
# 	trees: 11, Out-of-bag evaluation: accuracy:0.824462 logloss:3.0257
# 	trees: 21, Out-of-bag evaluation: accuracy:0.821348 logloss:2.02129
# 	trees: 31, Out-of-bag evaluation: accuracy:0.82809 logloss:1.59993
# 	trees: 41, Out-of-bag evaluation: accuracy:0.824719 logloss:1.45047
# 	trees: 51, Out-of-bag evaluation: accuracy:0.830337 logloss:1.33887
# 	trees: 61, Out-of-bag evaluation: accuracy:0.834831 logloss:1.26064
# 	trees: 71, Out-of-bag evaluation: accuracy:0.830337 logloss:1.14727
# 	trees: 81, Out-of-bag evaluation: accuracy:0.833708 logloss:1.07638
# 	trees: 91, Out-of-bag evaluation: accuracy:0.830337 logloss:1.00338
# 	trees: 101, Out-of-bag evaluation: accuracy:0.825843 logloss:0.966691
# 	trees: 111, Out-of-bag evaluation: accuracy:0.825843 logloss:0.85861
# 	trees: 121, Out-of-bag evaluation: accuracy:0.826966 logloss:0.675905
# 	trees: 131, Out-of-bag evaluation: accuracy:0.823596 logloss:0.677509
# 	trees: 141, Out-of-bag evaluation: accuracy:0.823596 logloss:0.568766
# 	trees: 151, Out-of-bag evaluation: accuracy:0.825843 logloss:0.568806
# 	trees: 161, Out-of-bag evaluation: accuracy:0.824719 logloss:0.569675
# 	trees: 172, Out-of-bag evaluation: accuracy:0.824719 logloss:0.570168
# 	trees: 183, Out-of-bag evaluation: accuracy:0.825843 logloss:0.572782
# 	trees: 193, Out-of-bag evaluation: accuracy:0.823596 logloss:0.571377
# 	trees: 203, Out-of-bag evaluation: accuracy:0.826966 logloss:0.571283
# 	trees: 213, Out-of-bag evaluation: accuracy:0.822472 logloss:0.570475
# 	trees: 223, Out-of-bag evaluation: accuracy:0.824719 logloss:0.532392
# 	trees: 233, Out-of-bag evaluation: accuracy:0.822472 logloss:0.533455
# 	trees: 245, Out-of-bag evaluation: accuracy:0.824719 logloss:0.532388
# 	trees: 255, Out-of-bag evaluation: accuracy:0.82809 logloss:0.532399
# 	trees: 265, Out-of-bag evaluation: accuracy:0.829214 logloss:0.533568
# 	trees: 275, Out-of-bag evaluation: accuracy:0.831461 logloss:0.533211
# 	trees: 285, Out-of-bag evaluation: accuracy:0.830337 logloss:0.533058
# 	trees: 295, Out-of-bag evaluation: accuracy:0.829214 logloss:0.533851
# 	trees: 300, Out-of-bag evaluation: accuracy:0.830337 logloss:0.534503

# %%
# The model have an accuracy of 0.830337 in the training set

# %%
# The feature importances (we can see this in the summary as well)
# model_rf.make_inspector().variable_importances()

# %%
# See the balance between model size and model quality

logs = model_rf.make_inspector().training_logs()

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")

plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")

plt.show()

# %%
# make predictions about the test set of Titanic wich has no labels:

# if you have a test set without label (our case) and has to make predictions:
predictions_rf = model_rf.predict(test_ds) # numpy array

# transform into 0's and 1's according to the classification threshold  
predictions_rf = (predictions_rf > classification_threshold).astype(int)

# check if there are any problems (Nan's)
if np.sum(np.isnan(predictions_rf))==0:
    print("Zero NaN's")
else:
    print("There are {} NaN's".format(np.sum(np.isnan(predictions_rf))) )
# Out:
# Zero NaN's

# %%
# creates the submission file

# gets the PassengerId column of the test data
passengerid_df = pd.DataFrame(test_df_treated["PassengerId"], columns=["PassengerId"])
# transforms predicions into dataframe
predictions_df = pd.DataFrame(predictions_rf, columns=["Survived"])

# join in one dataframe with two columns
submission_df = pd.concat([passengerid_df, predictions_df], axis=1)

# checks again if everything is alright
print(submission_df)

# save the predictions into a csv file
submission_df.to_csv("TitanicPredictions_RandomForest_TF.csv", index=False, sep=",")
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# #### *3.2.2 Random Forests - TensorFlow*
# #### Results
#
# This model ended up with number of trees equal to 300, accuracy = 0.830337, logloss = 0.534503.
#
# It could be downgraded to about 150 trees where after that number the logloss and the accuracy doesn't change much.
#
# This model used all the 13 columns of data.
#
# After submitting to Kaggle these predictions get an Score of 0.78708

# %% [markdown]
# ### *4.3 Gradient Boosted Trees - TensorFlow*
#
# #### Now use the third method, Gradient Boosted Trees (GBT)

# %%
# Train a Gradient Boosted Trees model.
model_gbt = tfdf.keras.GradientBoostedTreesModel(verbose=0)
fitting = model_gbt.fit(train_ds)

# Calling compile on the model before the fit is optional. 
# Compile can be used to provide extra evaluation metrics.
# Out:
# 14/14 [==============================] - 0s 2ms/step
# [INFO kernel.cc:736] Start Yggdrasil model training
# [INFO kernel.cc:737] Collect training examples
# [INFO kernel.cc:392] Number of batches: 14
# [INFO kernel.cc:393] Number of examples: 890
# [INFO data_spec_inference.cc:290] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO data_spec_inference.cc:290] 890 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO data_spec_inference.cc:290] 672 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO kernel.cc:759] Dataset:
# Number of records: 890
# Number of columns: 13
#
# Number of columns by type:
# 	NUMERICAL: 7 (53.8462%)
# 	CATEGORICAL: 6 (46.1538%)
#
# Columns:
#
# NUMERICAL: 7 (53.8462%)
# 	0: "Age" NUMERICAL mean:29.2669 min:0.42 max:80 sd:13.2484
# 	3: "FamilySize" NUMERICAL mean:0.905618 min:0 max:10 sd:1.61317
# 	4: "Fare" NUMERICAL mean:0.0629121 min:0 max:1 sd:0.0969819
# 	6: "Parch" NUMERICAL mean:0.382022 min:0 max:6 sd:0.805956
# 	7: "PassengerId" NUMERICAL mean:445.5 min:1 max:890 sd:256.921
# 	8: "Pclass" NUMERICAL mean:2.30787 min:1 max:3 sd:0.83575
# 	10: "SibSp" NUMERICAL mean:0.523596 min:0 max:8 sd:1.1026
#
# CATEGORICAL: 6 (46.1538%)
# 	1: "Cabin" CATEGORICAL num-nas:686 (77.0787%) has-dict vocab-size:1 num-oods:147 (72.0588%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224719%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.5225%)
# 	5: "Name" CATEGORICAL has-dict vocab-size:1 num-oods:890 (100%)
# 	9: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 576 (64.7191%)
# 	11: "Ticket" CATEGORICAL has-dict vocab-size:9 num-oods:672 (75.5056%) most-frequent:"<OOD>" 672 (75.5056%)
# 	12: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute which type is manually defined by the user i.e. the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO kernel.cc:762] Configure learner
# [WARNING gradient_boosted_trees.cc:1643] Subsample hyperparameter given but sampling method does not match.
# [WARNING gradient_boosted_trees.cc:1656] GOSS alpha hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1665] GOSS beta hyperparameter given but GOSS is disabled.
# [WARNING gradient_boosted_trees.cc:1677] SelGB ratio hyperparameter given but SelGB is disabled.
# [INFO kernel.cc:787] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "Age"
# features: "Cabin"
# features: "Embarked"
# features: "FamilySize"
# features: "Fare"
# features: "Name"
# features: "Parch"
# features: "PassengerId"
# features: "Pclass"
# features: "Sex"
# features: "SibSp"
# features: "Ticket"
# label: "__LABEL"
# task: CLASSIFICATION
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     num_candidate_attributes_ratio: -1
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#   }
#   shrinkage: 0.1
#   validation_set_ratio: 0.1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   apply_link_function: true
#   compute_permutation_variable_importance: false
# }
#
# [INFO kernel.cc:790] Deployment config:
# num_threads: 6
#
# [INFO kernel.cc:817] Train model
# [INFO gradient_boosted_trees.cc:404] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# [INFO gradient_boosted_trees.cc:1001] Training gradient boosted tree on 890 example(s) and 12 feature(s).
# [INFO gradient_boosted_trees.cc:1044] 817 examples used for training and 73 examples used for validation
# [INFO gradient_boosted_trees.cc:1426] 	num-trees:1 train-loss:1.237421 train-accuracy:0.611995 valid-loss:1.205384 valid-accuracy:0.657534
# [INFO gradient_boosted_trees.cc:1428] 	num-trees:2 train-loss:1.152391 train-accuracy:0.753978 valid-loss:1.130693 valid-accuracy:0.794521
# [INFO gradient_boosted_trees.cc:2740] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.691526
# [INFO gradient_boosted_trees.cc:229] Truncates the model to 23 tree(s) i.e. 23  iteration(s).
# [INFO gradient_boosted_trees.cc:263] Final model num-trees:23 valid-loss:0.691526 valid-accuracy:0.835616
# [INFO kernel.cc:828] Export model in log directory: /tmp/tmpfk69vror
# [INFO kernel.cc:836] Save model in resources
# [INFO kernel.cc:988] Loading model from path
# [INFO abstract_model.cc:993] Engine "GradientBoostedTreesQuickScorerExtended" built
# [INFO kernel.cc:848] Use fast generic engine

# %%
# Check the Summary of the GBT model.
model_gbt.summary()

# Type: The learning algorithm used to train the model (Random Forest in our case).
# Task: The problem solved by the model (Classification in our case).
# Input Features: The input features of the model.
# Variable Importance: Different measures of the importance of each feature for the model.
# Out-of-bag evaluation: The out-of-bag evaluation of the model. This is a cheap and efficient alternative to cross-validation.
# Number of {trees, nodes} and other metrics: Statistics about the structure of the decisions forests.
# Out:
# Model: "gradient_boosted_trees_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "GRADIENT_BOOSTED_TREES"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (12):
# 	Age
# 	Cabin
# 	Embarked
# 	FamilySize
# 	Fare
# 	Name
# 	Parch
# 	PassengerId
# 	Pclass
# 	Sex
# 	SibSp
# 	Ticket
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.       "Cabin"  4.680707 ################
#     2.        "Name"  4.680707 ################
#     3.     "__LABEL"  4.680707 ################
#     4.       "SibSp"  4.427538 ##############
#     5.       "Parch"  4.405206 ##############
#     6.    "Embarked"  4.148156 #############
#     7.  "FamilySize"  3.851532 ###########
#     8. "PassengerId"  3.653351 ##########
#     9.      "Ticket"  3.514163 #########
#    10.         "Age"  2.976425 ######
#    11.        "Fare"  2.968970 ######
#    12.      "Pclass"  2.705120 #####
#    13.         "Sex"  1.670616
#
# Variable Importance: NUM_AS_ROOT:
#     1.      "Sex"  9.000000 ################
#     2.   "Pclass"  5.000000 ########
#     3.     "Fare"  4.000000 ######
#     4. "Embarked"  2.000000 ##
#     5.   "Ticket"  2.000000 ##
#     6.      "Age"  1.000000
#
# Variable Importance: NUM_NODES:
#     1.         "Age" 107.000000 ################
#     2. "PassengerId" 104.000000 ###############
#     3.        "Fare" 94.000000 #############
#     4.      "Pclass" 39.000000 ####
#     5.         "Sex" 39.000000 ####
#     6.      "Ticket" 37.000000 ###
#     7.  "FamilySize" 34.000000 ###
#     8.       "SibSp" 23.000000 #
#     9.       "Parch" 16.000000
#    10.    "Embarked" 15.000000
#
# Variable Importance: SUM_SCORE:
#     1.         "Sex" 272.235186 ################
#     2.        "Fare" 78.673119 ####
#     3.         "Age" 72.943137 ####
#     4.      "Pclass" 67.866624 ###
#     5. "PassengerId" 48.280516 ##
#     6.      "Ticket" 29.417269 #
#     7.       "SibSp" 24.380710 #
#     8.  "FamilySize" 20.378377
#     9.    "Embarked" 10.325925
#    10.       "Parch"  5.821310
#
#
#
# Loss: BINOMIAL_LOG_LIKELIHOOD
# Validation loss value: 0.691526
# Number of trees per iteration: 1
# Node format: NOT_SET
# Number of trees: 23
# Total number of nodes: 1039
#
# Number of nodes by tree:
# Count: 23 Average: 45.1739 StdDev: 6.59151
# Min: 29 Max: 53 Ignored: 0
# ----------------------------------------------
# [ 29, 30) 1   4.35%   4.35% ##
# [ 30, 31) 0   0.00%   4.35%
# [ 31, 32) 0   0.00%   4.35%
# [ 32, 34) 0   0.00%   4.35%
# [ 34, 35) 0   0.00%   4.35%
# [ 35, 36) 2   8.70%  13.04% ####
# [ 36, 37) 0   0.00%  13.04%
# [ 37, 39) 0   0.00%  13.04%
# [ 39, 40) 2   8.70%  21.74% ####
# [ 40, 41) 0   0.00%  21.74%
# [ 41, 42) 3  13.04%  34.78% ######
# [ 42, 44) 2   8.70%  43.48% ####
# [ 44, 45) 0   0.00%  43.48%
# [ 45, 46) 1   4.35%  47.83% ##
# [ 46, 47) 0   0.00%  47.83%
# [ 47, 49) 0   0.00%  47.83%
# [ 49, 50) 5  21.74%  69.57% ##########
# [ 50, 51) 0   0.00%  69.57%
# [ 51, 52) 4  17.39%  86.96% ########
# [ 52, 53] 3  13.04% 100.00% ######
#
# Depth by leafs:
# Count: 531 Average: 4.69868 StdDev: 0.604112
# Min: 2 Max: 5 Ignored: 0
# ----------------------------------------------
# [ 2, 3)   4   0.75%   0.75%
# [ 3, 4)  29   5.46%   6.21% #
# [ 4, 5)  90  16.95%  23.16% ##
# [ 5, 5] 408  76.84% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 531 Average: 35.3879 StdDev: 60.0637
# Min: 5 Max: 392 Ignored: 0
# ----------------------------------------------
# [   5,  24) 358  67.42%  67.42% ##########
# [  24,  43)  51   9.60%  77.02% #
# [  43,  63)  47   8.85%  85.88% #
# [  63,  82)  20   3.77%  89.64% #
# [  82, 102)   7   1.32%  90.96%
# [ 102, 121)  13   2.45%  93.41%
# [ 121, 140)   3   0.56%  93.97%
# [ 140, 160)   5   0.94%  94.92%
# [ 160, 179)   5   0.94%  95.86%
# [ 179, 199)   3   0.56%  96.42%
# [ 199, 218)   3   0.56%  96.99%
# [ 218, 237)   3   0.56%  97.55%
# [ 237, 257)   1   0.19%  97.74%
# [ 257, 276)   2   0.38%  98.12%
# [ 276, 296)   0   0.00%  98.12%
# [ 296, 315)   1   0.19%  98.31%
# [ 315, 334)   2   0.38%  98.68%
# [ 334, 354)   5   0.94%  99.62%
# [ 354, 373)   1   0.19%  99.81%
# [ 373, 392]   1   0.19% 100.00%
#
# Attribute in nodes:
# 	107 : Age [NUMERICAL]
# 	104 : PassengerId [NUMERICAL]
# 	94 : Fare [NUMERICAL]
# 	39 : Sex [CATEGORICAL]
# 	39 : Pclass [NUMERICAL]
# 	37 : Ticket [CATEGORICAL]
# 	34 : FamilySize [NUMERICAL]
# 	23 : SibSp [NUMERICAL]
# 	16 : Parch [NUMERICAL]
# 	15 : Embarked [CATEGORICAL]
#
# Attribute in nodes with depth <= 0:
# 	9 : Sex [CATEGORICAL]
# 	5 : Pclass [NUMERICAL]
# 	4 : Fare [NUMERICAL]
# 	2 : Ticket [CATEGORICAL]
# 	2 : Embarked [CATEGORICAL]
# 	1 : Age [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	15 : Sex [CATEGORICAL]
# 	13 : Pclass [NUMERICAL]
# 	10 : Ticket [CATEGORICAL]
# 	9 : Fare [NUMERICAL]
# 	8 : Age [NUMERICAL]
# 	6 : FamilySize [NUMERICAL]
# 	4 : PassengerId [NUMERICAL]
# 	2 : Embarked [CATEGORICAL]
# 	1 : SibSp [NUMERICAL]
# 	1 : Parch [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	32 : Age [NUMERICAL]
# 	26 : Sex [CATEGORICAL]
# 	20 : Ticket [CATEGORICAL]
# 	19 : Fare [NUMERICAL]
# 	18 : Pclass [NUMERICAL]
# 	17 : PassengerId [NUMERICAL]
# 	14 : FamilySize [NUMERICAL]
# 	5 : SibSp [NUMERICAL]
# 	3 : Parch [NUMERICAL]
# 	3 : Embarked [CATEGORICAL]
#
# Attribute in nodes with depth <= 3:
# 	62 : Age [NUMERICAL]
# 	52 : Fare [NUMERICAL]
# 	49 : PassengerId [NUMERICAL]
# 	36 : Sex [CATEGORICAL]
# 	28 : Ticket [CATEGORICAL]
# 	25 : Pclass [NUMERICAL]
# 	21 : FamilySize [NUMERICAL]
# 	12 : SibSp [NUMERICAL]
# 	12 : Parch [NUMERICAL]
# 	7 : Embarked [CATEGORICAL]
#
# Attribute in nodes with depth <= 5:
# 	107 : Age [NUMERICAL]
# 	104 : PassengerId [NUMERICAL]
# 	94 : Fare [NUMERICAL]
# 	39 : Sex [CATEGORICAL]
# 	39 : Pclass [NUMERICAL]
# 	37 : Ticket [CATEGORICAL]
# 	34 : FamilySize [NUMERICAL]
# 	23 : SibSp [NUMERICAL]
# 	16 : Parch [NUMERICAL]
# 	15 : Embarked [CATEGORICAL]
#
# Condition type in nodes:
# 	417 : HigherCondition
# 	91 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	13 : ContainsBitmapCondition
# 	10 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	42 : HigherCondition
# 	27 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	108 : HigherCondition
# 	49 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	233 : HigherCondition
# 	71 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	417 : HigherCondition
# 	91 : ContainsBitmapCondition

# %%
# See the balance between model size and model quality

logs = model_gbt.make_inspector().training_logs()

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")

plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")

plt.show()

# it seems to have an overfitting at 20 trees.
# the accuracy doesn't change much after that as well

# %%
all# make predictions about the test set of Titanic wich has no labels:

# if you have a test set without label (our case) and has to make predictions:
predictions_gbt = model_gbt.predict(test_ds) # numpy array

# transform into 0's and 1's according to the classification threshold  
predictions_gbt = (predictions_gbt > classification_threshold).astype(int)

# check if there are any problems (Nan's)
if np.sum(np.isnan(predictions_gbt))==0:
    print("Zero NaN's")
else:
    print("There are {} NaN's".format(np.sum(np.isnan(predictions_gbt))) )
# Out:
# Zero NaN's

# %%
# creates the submission file

# gets the PassengerId column of the test data
passengerid_df = pd.DataFrame(test_df_treated["PassengerId"], columns=["PassengerId"])
# transforms predicions into dataframe
predictions_df = pd.DataFrame(predictions_gbt, columns=["Survived"])

# join in one dataframe with two columns
submission_df = pd.concat([passengerid_df, predictions_df], axis=1)

# checks again if everything is alright
print(submission_df)

# save the predictions into a csv file
submission_df.to_csv("TitanicPredictions_GradientBoostedTrees_TF.csv", index=False, sep=",")
# save in kaggle output
submission_df.to_csv('/kaggle/working/TitanicPredictions_GradientBoostedTrees_TF.csv',index=False, sep=",")



import os
os.chdir(r'../working')
submission_df.to_csv(r'TitanicPredictions_GradientBoostedTrees_TF.csv')
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
from IPython.display import FileLink
FileLink(r'TitanicPredictions_GradientBoostedTrees_TF.csv')
# Out:
# /kaggle/working/TitanicPredictions_GradientBoostedTrees_TF.csv

# %% [markdown]
# #### *3.3.2 Gradient Boosted Trees - TensorFlow*
# #### Results
#
# This model ended up with number of trees equal to 23, valid-loss = 0.691526, valid accuracy = 0.835616.
#
# This shows that in fact it doesn't make sense to use more than 20 and so trees as i mentioned after the Logloss graph.
#
# This model used all the 13 columns of data.
#
# After submitting to Kaggle these predictions get an Score of 0.78468 an ended up in place 1602 of 15192 people.
